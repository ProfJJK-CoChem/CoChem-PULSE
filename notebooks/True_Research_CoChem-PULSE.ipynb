# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE")
tests_dir = module_dir / "tests"

print(f"[CoChem-PULSE] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-PULSE.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-PULSE] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE
# plugins: anyio-4.10.0
# collecting ... collected 19 items
#
# tests/test_empirical_m4.py::test_landau_zener_zero_coupling_empirical PASSED [  5%]
# tests/test_empirical_m4.py::test_vtst_and_troe_dependencies_empirical PASSED [ 10%]
# tests/test_empirical_m4.py::test_fssh_bit_for_bit_reproducibility_empirical PASSED [ 15%]
# tests/test_empirical_m4.py::test_velocity_verlet_energy_conservation_empirical PASSED [ 21%]
# tests/test_pulse_core.py::test_swarm_manager_validation PASSED           [ 26%]
# tests/test_pulse_core.py::test_laser_simulation PASSED                   [ 31%]
# tests/test_pulse_core.py::test_nacv_and_velocity_scaling PASSED          [ 36%]
# tests/test_pulse_core.py::test_decoherence_and_kill_switch PASSED        [ 42%]
# tests/test_pulse_core.py::test_aimnet2_nse_calculator PASSED             [ 47%]
# tests/test_pulse_core.py::test_viz_and_dispatcher PASSED                 [ 52%]
# tests/test_pulse_core.py::test_aimnet2_nse_physical_gap_and_provenance PASSED [ 57%]
# tests/test_pulse_core.py::test_jensen_inequality_rotational_constants PASSED [ 63%]
# tests/test_pulse_core.py::test_hdf5_state_chaining_and_rotational_constants PASSED [ 68%]
# tests/test_pulse_core.py::test_cuda_mps_payload_config PASSED            [ 73%]
# tests/test_pulse_core.py::test_diatomic_linear_rotor_jensen_inequality PASSED [ 78%]
# tests/test_rk4.py::test_rk4_norm_preservation PASSED                     [ 84%]
# tests/test_rk4.py::test_evaluate_hop_frustrated PASSED                   [ 89%]
# tests/test_wigner.py::test_wigner_sampling_shapes_and_types PASSED       [ 94%]
# tests/test_wigner.py::test_wigner_variance_non_zero PASSED               [100%]
#
# ============================= 19 passed in 3.68s ==============================
#
# ✅ Genuine Native Execution Complete.
